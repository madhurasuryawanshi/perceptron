# %%
#Madhura Suryawanshi CWID: 887445005
#Anjali Iyer CWID: 887478717
#ANN Project 1
#Run this file for output

import numpy as np
from dataset import TRAINING_DATA,TEST_DATA
# %run percep.ipynb
# %run label.ipynb


def char2vec(char):
    return [
        -1 if pixel == '.' else 1                    #vector representation of raw input
        for line in char
        for pixel in line
    ]

characters = {'A':0, 'B':1, 'C':2, 'D':3, 'E':4, 
              'F':5, 'G':6, 'H':7, 'I':8, 'J':9,             #dictionary for mapping characters to index
              'K':10, 'L':11, 'M':12, 'N':13, 'O':14, 
              'P':15, 'Q':16, 'R':17, 'S':18, 'T':19, 
              'U':20, 'V':21, 'W':22, 'X':23, 'Y':24,'Z':25,}

key_list = list(characters.keys())
value_list = list(characters.values())

training_inputs = []
perceptron = []

for i in range(len(TRAINING_DATA)):                               #loop for training all pereceptrons and plotting 
    training_inputs.append(np.array(char2vec(TRAINING_DATA[i])))  #the errors vs epoch for each perceptron
    perceptron.append(Perceptron(35))
    print("Plot for Perceptron",key_list[value_list.index(i)])
    perceptron[i].train(training_inputs, labels[i])
               

char = input("Please enter character from TEST DATA:")  #for selecting item from test data #scroll down
char1 = input("Please enter perceptron to be tested:")  #for predecting perceptron against test data #scroll down 

inputs = [np.array(char2vec(TEST_DATA[characters.get(char)]))]
perceptron[characters.get(char1)].predict(inputs)
# Out:
# Plot for Perceptron A
# Plot for Perceptron B
# Plot for Perceptron C
# Plot for Perceptron D
# Plot for Perceptron E
# Plot for Perceptron F
# Plot for Perceptron G
# Plot for Perceptron H
# Plot for Perceptron I
# Plot for Perceptron J
# Plot for Perceptron K
# Plot for Perceptron L
# Plot for Perceptron M
# Plot for Perceptron N
# Plot for Perceptron O
# Plot for Perceptron P
# Plot for Perceptron Q
# Plot for Perceptron R
# Plot for Perceptron S
# Plot for Perceptron T
# Plot for Perceptron U
# Plot for Perceptron V
# Plot for Perceptron W
# Plot for Perceptron X
# Plot for Perceptron Y
# Plot for Perceptron Z
# Please enter character from TEST DATA:Y
# Please enter perceptron to be tested:O
# 0
